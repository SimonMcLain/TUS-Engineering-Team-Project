# %%
import os
import datetime

import IPython
import IPython.display
import seaborn as sns
import keras
import tensorflow as tf
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np

# %% [markdown]
# stat_path = input("Enter path to daily detailed statistics: ")

# %% [markdown]
# lab_path = input("Enter path to daily lab testing figures:")

# %% [markdown]
# vacc_path = input("Enter path to daily vaccination figures")

# %% [markdown]
# boost_path = input("Enter path to daily booster figures: ")

# %%
owd_path = input("Enter path to Our World in data file: ")
# Out:
# Enter path to Our World in data file: /Users/simonmclain/Documents/Documents/Software Development with AI/Semister 4/Engineering Team Project/TUS-Engineering-Team-Project/Data

# %%
filename = '/owid-covid-data.csv'

# %%
path = owd_path + filename

# %%
df = pd.read_csv(path)

# %%
#df.location.unique()

# %%
df_irl = df.location.isin(['Ireland'])

# %%
df = df[df_irl]

# %%
df.shape
# Out:
# (717, 67)

# %%
df.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'new_tests', 'total_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
#        'new_vaccinations', 'new_vaccinations_smoothed',
#        'total_vaccinations_per_hundred', 'people_vaccinated_per_hundred',
#        'people_fully_vaccinated_per_hundred', 'total_boosters_per_hundred',
#        'new_vaccinations_smoothed_per_million',
#        'new_people_vaccinated_smoothed',
#        'new_people_vaccinated_smoothed_per_hundred', 'stringency_index',
#        'population', 'population_density', 'median_age', 'aged_65_older',
#        'aged_70_older', 'gdp_per_capita', 'extreme_poverty',
#        'cardiovasc_death_rate', 'diabetes_prevalence', 'female_smokers',
#        'male_smokers', 'handwashing_facilities', 'hospital_beds_per_thousand',
#        'life_expectancy', 'human_development_index',
#        'excess_mortality_cumulative_absolute', 'excess_mortality_cumulative',
#        'excess_mortality', 'excess_mortality_cumulative_per_million'],
#       dtype='object')

# %%
df.reset_index(inplace=True)

# %%
df.drop(columns=['iso_code', 'continent','weekly_icu_admissions',
       'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
       'weekly_hosp_admissions_per_million', 'location','tests_units','handwashing_facilities'], inplace=True)

# %%
df.drop(columns=['index'], inplace=True)

# %%
df.drop(df.index[:10], inplace=True)

# %%
df=df.fillna(0)

# %%
df.shape
# Out:
# (707, 58)

# %%
df.tail()
# Out:
#            date  total_cases  new_cases  new_cases_smoothed  total_deaths  \
# 712  10/02/2022    1236188.0     5649.0            5281.571        6291.0
# 713  11/02/2022    1242806.0     6618.0            5270.286        6291.0
# 714  12/02/2022    1242806.0        0.0            5270.286        6291.0
# 715  13/02/2022    1242806.0        0.0            5270.286        6291.0
# 716  14/02/2022    1255571.0    12765.0            4927.000        6291.0
#
#      new_deaths  new_deaths_smoothed  total_cases_per_million  \
# 712         0.0                  0.0               248085.855
# 713         0.0                  0.0               249413.996
# 714         0.0                  0.0               249413.996
# 715         0.0                  0.0               249413.996
# 716         0.0                  0.0               251975.756
#
#      new_cases_per_million  new_cases_smoothed_per_million  ...  \
# 712               1133.676                        1059.938  ...
# 713               1328.141                        1057.674  ...
# 714                  0.000                        1057.674  ...
# 715                  0.000                        1057.674  ...
# 716               2561.759                         988.781  ...
#
#      diabetes_prevalence  female_smokers  male_smokers  \
# 712                 3.28            23.0          25.7
# 713                 3.28            23.0          25.7
# 714                 3.28            23.0          25.7
# 715                 3.28            23.0          25.7
# 716                 3.28            23.0          25.7
#
#      hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 712                        2.96             82.3                    0.955
# 713                        2.96             82.3                    0.955
# 714                        2.96             82.3                    0.955
# 715                        2.96             82.3                    0.955
# 716                        2.96             82.3                    0.955
#
#      excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 712                                   0.0                          0.0
# 713                                   0.0                          0.0
# 714                                   0.0                          0.0
# 715                                   0.0                          0.0
# 716                                   0.0                          0.0
#
#      excess_mortality  excess_mortality_cumulative_per_million
# 712               0.0                                      0.0
# 713               0.0                                      0.0
# 714               0.0                                      0.0
# 715               0.0                                      0.0
# 716               0.0                                      0.0
#
# [5 rows x 58 columns]

# %%
df.describe().transpose()
# Out:
#                                             count          mean           std  \
# total_cases                                 707.0  2.540246e+05  2.826402e+05
# new_cases                                   707.0  1.775884e+03  3.863402e+03
# new_cases_smoothed                          707.0  1.752978e+03  3.392645e+03
# total_deaths                                707.0  3.527710e+03  1.850364e+03
# new_deaths                                  707.0  8.898161e+00  1.853512e+01
# new_deaths_smoothed                         707.0  8.821778e+00  1.250059e+01
# total_cases_per_million                     707.0  5.097922e+04  5.672198e+04
# new_cases_per_million                       707.0  3.563954e+02  7.753314e+02
# new_cases_smoothed_per_million              707.0  3.517985e+02  6.808570e+02
# total_deaths_per_million                    707.0  7.079626e+02  3.713425e+02
# new_deaths_per_million                      707.0  1.785730e+00  3.719746e+00
# new_deaths_smoothed_per_million             707.0  1.770410e+00  2.508736e+00
# reproduction_rate                           707.0  1.068458e+00  3.592052e-01
# icu_patients                                707.0  5.981047e+01  4.940712e+01
# icu_patients_per_million                    707.0  1.200312e+01  9.915325e+00
# hosp_patients                               707.0  3.716393e+02  3.799439e+02
# hosp_patients_per_million                   707.0  7.458289e+01  7.624951e+01
# new_tests                                   707.0  1.580152e+04  9.243672e+03
# total_tests                                 707.0  4.043353e+06  3.335100e+06
# total_tests_per_thousand                    707.0  8.114451e+02  6.693085e+02
# new_tests_per_thousand                      707.0  3.171136e+00  1.855090e+00
# new_tests_smoothed                          707.0  1.573207e+04  8.867820e+03
# new_tests_smoothed_per_thousand             707.0  3.157201e+00  1.779642e+00
# positive_rate                               707.0  7.634144e-02  9.574831e-02
# tests_per_case                              707.0  4.992928e+01  9.364403e+01
# total_vaccinations                          707.0  2.865658e+06  3.626560e+06
# people_vaccinated                           707.0  1.439825e+06  1.680219e+06
# people_fully_vaccinated                     707.0  1.245712e+06  1.616522e+06
# total_boosters                              707.0  2.567392e+05  6.995625e+05
# new_vaccinations                            707.0  1.480445e+04  1.997993e+04
# new_vaccinations_smoothed                   707.0  1.482246e+04  1.815685e+04
# total_vaccinations_per_hundred              707.0  5.750979e+01  7.277992e+01
# people_vaccinated_per_hundred               707.0  2.889529e+01  3.371963e+01
# people_fully_vaccinated_per_hundred         707.0  2.499948e+01  3.244127e+01
# total_boosters_per_hundred                  707.0  5.152405e+00  1.403922e+01
# new_vaccinations_smoothed_per_million       707.0  2.974678e+03  3.643827e+03
# new_people_vaccinated_smoothed              707.0  5.708905e+03  8.731898e+03
# new_people_vaccinated_smoothed_per_hundred  707.0  1.145771e-01  1.752465e-01
# stringency_index                            707.0  6.185306e+01  1.996252e+01
# population                                  707.0  4.982904e+06  0.000000e+00
# population_density                          707.0  6.987400e+01  1.422092e-14
# median_age                                  707.0  3.870000e+01  1.422092e-14
# aged_65_older                               707.0  1.392800e+01  1.777614e-15
# aged_70_older                               707.0  8.678000e+00  1.777614e-15
# gdp_per_capita                              707.0  6.733529e+04  1.456222e-11
# extreme_poverty                             707.0  2.000000e-01  5.555045e-17
# cardiovasc_death_rate                       707.0  1.264590e+02  4.266275e-14
# diabetes_prevalence                         707.0  3.280000e+00  4.444036e-16
# female_smokers                              707.0  2.300000e+01  0.000000e+00
# male_smokers                                707.0  2.570000e+01  7.110458e-15
# hospital_beds_per_thousand                  707.0  2.960000e+00  4.444036e-16
# life_expectancy                             707.0  8.230000e+01  1.422092e-14
# human_development_index                     707.0  9.550000e-01  0.000000e+00
# excess_mortality_cumulative_absolute        707.0  2.240792e+01  1.608886e+02
# excess_mortality_cumulative                 707.0  5.760962e-02  4.457560e-01
# excess_mortality                            707.0  1.318105e-01  1.903324e+00
# excess_mortality_cumulative_per_million     707.0  4.496960e+00  3.228811e+01
#
#                                                      min           25%  \
# total_cases                                 3.400000e+01  2.916000e+04
# new_cases                                  -1.707000e+03  2.495000e+02
# new_cases_smoothed                          4.571000e+00  2.818570e+02
# total_deaths                                0.000000e+00  1.777000e+03
# new_deaths                                 -5.000000e+00  0.000000e+00
# new_deaths_smoothed                        -1.430000e-01  1.571000e+00
# total_cases_per_million                     6.823000e+00  5.852010e+03
# new_cases_per_million                      -3.425710e+02  5.007150e+01
# new_cases_smoothed_per_million              9.170000e-01  5.656450e+01
# total_deaths_per_million                    0.000000e+00  3.566190e+02
# new_deaths_per_million                     -1.003000e+00  0.000000e+00
# new_deaths_smoothed_per_million            -2.900000e-02  3.150000e-01
# reproduction_rate                           0.000000e+00  8.700000e-01
# icu_patients                                0.000000e+00  2.200000e+01
# icu_patients_per_million                    0.000000e+00  4.415000e+00
# hosp_patients                               0.000000e+00  9.550000e+01
# hosp_patients_per_million                   0.000000e+00  1.916550e+01
# new_tests                                   0.000000e+00  9.537500e+03
# total_tests                                 0.000000e+00  8.584585e+05
# total_tests_per_thousand                    0.000000e+00  1.722805e+02
# new_tests_per_thousand                      0.000000e+00  1.914000e+00
# new_tests_smoothed                          0.000000e+00  8.874000e+03
# new_tests_smoothed_per_thousand             0.000000e+00  1.781000e+00
# positive_rate                               0.000000e+00  2.265000e-02
# tests_per_case                              0.000000e+00  9.950000e+00
# total_vaccinations                          0.000000e+00  0.000000e+00
# people_vaccinated                           0.000000e+00  0.000000e+00
# people_fully_vaccinated                     0.000000e+00  0.000000e+00
# total_boosters                              0.000000e+00  0.000000e+00
# new_vaccinations                            0.000000e+00  0.000000e+00
# new_vaccinations_smoothed                   0.000000e+00  0.000000e+00
# total_vaccinations_per_hundred              0.000000e+00  0.000000e+00
# people_vaccinated_per_hundred               0.000000e+00  0.000000e+00
# people_fully_vaccinated_per_hundred         0.000000e+00  0.000000e+00
# total_boosters_per_hundred                  0.000000e+00  0.000000e+00
# new_vaccinations_smoothed_per_million       0.000000e+00  0.000000e+00
# new_people_vaccinated_smoothed              0.000000e+00  0.000000e+00
# new_people_vaccinated_smoothed_per_hundred  0.000000e+00  0.000000e+00
# stringency_index                            0.000000e+00  4.444000e+01
# population                                  4.982904e+06  4.982904e+06
# population_density                          6.987400e+01  6.987400e+01
# median_age                                  3.870000e+01  3.870000e+01
# aged_65_older                               1.392800e+01  1.392800e+01
# aged_70_older                               8.678000e+00  8.678000e+00
# gdp_per_capita                              6.733529e+04  6.733529e+04
# extreme_poverty                             2.000000e-01  2.000000e-01
# cardiovasc_death_rate                       1.264590e+02  1.264590e+02
# diabetes_prevalence                         3.280000e+00  3.280000e+00
# female_smokers                              2.300000e+01  2.300000e+01
# male_smokers                                2.570000e+01  2.570000e+01
# hospital_beds_per_thousand                  2.960000e+00  2.960000e+00
# life_expectancy                             8.230000e+01  8.230000e+01
# human_development_index                     9.550000e-01  9.550000e-01
# excess_mortality_cumulative_absolute       -4.170000e+02  0.000000e+00
# excess_mortality_cumulative                -4.680000e+00  0.000000e+00
# excess_mortality                           -9.050000e+00  0.000000e+00
# excess_mortality_cumulative_per_million    -8.368614e+01  0.000000e+00
#
#                                                      50%           75%  \
# total_cases                                 2.182510e+05  3.362730e+05
# new_cases                                   5.220000e+02  1.465500e+03
# new_cases_smoothed                          5.294290e+02  1.488643e+03
# total_deaths                                4.300000e+03  5.074000e+03
# new_deaths                                  1.000000e+00  9.000000e+00
# new_deaths_smoothed                         4.714000e+00  9.000000e+00
# total_cases_per_million                     4.379996e+04  6.748535e+04
# new_cases_per_million                       1.047580e+02  2.941055e+02
# new_cases_smoothed_per_million              1.062490e+02  2.987500e+02
# total_deaths_per_million                    8.629510e+02  1.018282e+03
# new_deaths_per_million                      2.010000e-01  1.806000e+00
# new_deaths_smoothed_per_million             9.460000e-01  1.806000e+00
# reproduction_rate                           1.020000e+00  1.250000e+00
# icu_patients                                4.600000e+01  8.850000e+01
# icu_patients_per_million                    9.232000e+00  1.776050e+01
# hosp_patients                               2.780000e+02  5.095000e+02
# hosp_patients_per_million                   5.579100e+01  1.022500e+02
# new_tests                                   1.528600e+04  2.059650e+04
# total_tests                                 3.505377e+06  6.573871e+06
# total_tests_per_thousand                    7.034810e+02  1.319285e+03
# new_tests_per_thousand                      3.068000e+00  4.133500e+00
# new_tests_smoothed                          1.591700e+04  2.028550e+04
# new_tests_smoothed_per_thousand             3.194000e+00  4.071000e+00
# positive_rate                               3.960000e-02  8.870000e-02
# tests_per_case                              2.190000e+01  4.280000e+01
# total_vaccinations                          3.990980e+05  6.655132e+06
# people_vaccinated                           2.532270e+05  3.627976e+06
# people_fully_vaccinated                     1.458840e+05  3.260052e+06
# total_boosters                              0.000000e+00  0.000000e+00
# new_vaccinations                            6.731000e+03  2.351750e+04
# new_vaccinations_smoothed                   8.113000e+03  2.760900e+04
# total_vaccinations_per_hundred              8.010000e+00  1.335600e+02
# people_vaccinated_per_hundred               5.080000e+00  7.281000e+01
# people_fully_vaccinated_per_hundred         2.930000e+00  6.542500e+01
# total_boosters_per_hundred                  0.000000e+00  0.000000e+00
# new_vaccinations_smoothed_per_million       1.628000e+03  5.540500e+03
# new_people_vaccinated_smoothed              1.115000e+03  9.068500e+03
# new_people_vaccinated_smoothed_per_hundred  2.200000e-02  1.820000e-01
# stringency_index                            5.556000e+01  8.148000e+01
# population                                  4.982904e+06  4.982904e+06
# population_density                          6.987400e+01  6.987400e+01
# median_age                                  3.870000e+01  3.870000e+01
# aged_65_older                               1.392800e+01  1.392800e+01
# aged_70_older                               8.678000e+00  8.678000e+00
# gdp_per_capita                              6.733529e+04  6.733529e+04
# extreme_poverty                             2.000000e-01  2.000000e-01
# cardiovasc_death_rate                       1.264590e+02  1.264590e+02
# diabetes_prevalence                         3.280000e+00  3.280000e+00
# female_smokers                              2.300000e+01  2.300000e+01
# male_smokers                                2.570000e+01  2.570000e+01
# hospital_beds_per_thousand                  2.960000e+00  2.960000e+00
# life_expectancy                             8.230000e+01  8.230000e+01
# human_development_index                     9.550000e-01  9.550000e-01
# excess_mortality_cumulative_absolute        0.000000e+00  0.000000e+00
# excess_mortality_cumulative                 0.000000e+00  0.000000e+00
# excess_mortality                            0.000000e+00  0.000000e+00
# excess_mortality_cumulative_per_million     0.000000e+00  0.000000e+00
#
#                                                      max
# total_cases                                 1.255571e+06
# new_cases                                   4.319900e+04
# new_cases_smoothed                          2.375200e+04
# total_deaths                                6.291000e+03
# new_deaths                                  2.200000e+02
# new_deaths_smoothed                         7.028600e+01
# total_cases_per_million                     2.519758e+05
# new_cases_per_million                       8.669443e+03
# new_cases_smoothed_per_million              4.766698e+03
# total_deaths_per_million                    1.262517e+03
# new_deaths_per_million                      4.415100e+01
# new_deaths_smoothed_per_million             1.410500e+01
# reproduction_rate                           2.840000e+00
# icu_patients                                2.210000e+02
# icu_patients_per_million                    4.435200e+01
# hosp_patients                               2.020000e+03
# hosp_patients_per_million                   4.053860e+02
# new_tests                                   4.899100e+04
# total_tests                                 1.117813e+07
# total_tests_per_thousand                    2.243297e+03
# new_tests_per_thousand                      9.832000e+00
# new_tests_smoothed                          4.465500e+04
# new_tests_smoothed_per_thousand             8.962000e+00
# positive_rate                               5.523000e-01
# tests_per_case                              6.830000e+02
# total_vaccinations                          1.050748e+07
# people_vaccinated                           4.038305e+06
# people_fully_vaccinated                     3.939271e+06
# total_boosters                              2.768440e+06
# new_vaccinations                            1.351550e+05
# new_vaccinations_smoothed                   9.134400e+04
# total_vaccinations_per_hundred              2.108700e+02
# people_vaccinated_per_hundred               8.104000e+01
# people_fully_vaccinated_per_hundred         7.906000e+01
# total_boosters_per_hundred                  5.556000e+01
# new_vaccinations_smoothed_per_million       1.833100e+04
# new_people_vaccinated_smoothed              3.491800e+04
# new_people_vaccinated_smoothed_per_hundred  7.010000e-01
# stringency_index                            9.074000e+01
# population                                  4.982904e+06
# population_density                          6.987400e+01
# median_age                                  3.870000e+01
# aged_65_older                               1.392800e+01
# aged_70_older                               8.678000e+00
# gdp_per_capita                              6.733529e+04
# extreme_poverty                             2.000000e-01
# cardiovasc_death_rate                       1.264590e+02
# diabetes_prevalence                         3.280000e+00
# female_smokers                              2.300000e+01
# male_smokers                                2.570000e+01
# hospital_beds_per_thousand                  2.960000e+00
# life_expectancy                             8.230000e+01
# human_development_index                     9.550000e-01
# excess_mortality_cumulative_absolute        2.066200e+03
# excess_mortality_cumulative                 4.250000e+00
# excess_mortality                            3.516000e+01
# excess_mortality_cumulative_per_million     4.146578e+02
