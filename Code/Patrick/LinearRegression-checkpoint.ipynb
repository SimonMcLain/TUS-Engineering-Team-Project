# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
df = pd.read_excel("preparedAndCleanedData.xlsx")
df.head()
# Out:
#         date  tests_per_case  new_vaccinations  \
# 0 2020-03-15             0.0                 0
# 1 2020-03-16             0.0                 0
# 2 2020-03-17             0.0                 0
# 3 2020-03-18             0.0                 0
# 4 2020-03-19             0.0                 0
#
#    Treatment and management of COVID-19: (Ireland)  Hand sanitizer: (Ireland)  \
# 0                                                1                         68
# 1                                                2                         38
# 2                                                2                         38
# 3                                                2                         38
# 4                                                2                         38
#
#    Face mask: (Ireland)  reproduction_rate  new_cases_smoothed
# 0                    18               2.51              15.714
# 1                    18               2.59              21.143
# 2                    18               2.70              27.000
# 3                    18               2.78              35.571
# 4                    18               2.84              73.429

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 701 entries, 0 to 700
# Data columns (total 8 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   date                                             701 non-null    datetime64[ns]
#  1   tests_per_case                                   701 non-null    float64
#  2   new_vaccinations                                 701 non-null    int64
#  3   Treatment and management of COVID-19: (Ireland)  701 non-null    int64
#  4   Hand sanitizer: (Ireland)                        701 non-null    int64
#  5   Face mask: (Ireland)                             701 non-null    int64
#  6   reproduction_rate                                701 non-null    float64
#  7   new_cases_smoothed                               701 non-null    float64
# dtypes: datetime64[ns](1), float64(3), int64(4)
# memory usage: 43.9 KB
# None

# %%
print(df.shape)
# Out:
# (701, 8)

# %%
df.describe()
# Out:
#        tests_per_case  new_vaccinations  \
# count      701.000000        701.000000
# mean        50.356633      14931.159772
# std         93.929861      20018.105179
# min          0.000000          0.000000
# 25%         10.400000          0.000000
# 50%         22.400000       6950.000000
# 75%         42.900000      23847.000000
# max        683.000000     135155.000000
#
#        Treatment and management of COVID-19: (Ireland)  \
# count                                       701.000000
# mean                                          0.271041
# std                                           0.466755
# min                                           0.000000
# 25%                                           0.000000
# 50%                                           0.000000
# 75%                                           1.000000
# max                                           2.000000
#
#        Hand sanitizer: (Ireland)  Face mask: (Ireland)  reproduction_rate  \
# count                 701.000000            701.000000         701.000000
# mean                    5.069900             16.352354           1.077603
# std                     6.083182             17.478884           0.346793
# min                     0.000000              3.000000           0.000000
# 25%                     2.000000              6.000000           0.880000
# 50%                     2.000000              9.000000           1.020000
# 75%                     7.000000             21.000000           1.250000
# max                    68.000000            100.000000           2.840000
#
#        new_cases_smoothed
# count          701.000000
# mean          1760.894639
# std           3401.837880
# min              6.571000
# 25%            286.429000
# 50%            535.571000
# 75%           1492.857000
# max          23752.000000

# %%
df['date'] = pd.to_numeric(pd.to_datetime(df['date']))

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 701 entries, 0 to 700
# Data columns (total 8 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   date                                             701 non-null    int64
#  1   tests_per_case                                   701 non-null    float64
#  2   new_vaccinations                                 701 non-null    int64
#  3   Treatment and management of COVID-19: (Ireland)  701 non-null    int64
#  4   Hand sanitizer: (Ireland)                        701 non-null    int64
#  5   Face mask: (Ireland)                             701 non-null    int64
#  6   reproduction_rate                                701 non-null    float64
#  7   new_cases_smoothed                               701 non-null    float64
# dtypes: float64(3), int64(5)
# memory usage: 43.9 KB
# None

# %%
target_column = ['new_cases_smoothed'] 
predictors = list(set(list(df.columns))-set(target_column))

# %%
data_numeric = df.select_dtypes(include=['float64', 'int64'])
plt.figure(figsize=(20, 10))
sns.pairplot(data_numeric)
plt.show()

# %%
X = df[predictors].values.reshape(-1,1)
y = df[target_column].values.reshape(-1,1)

# %%
reg = LinearRegression()
reg.fit(X, y)
predictions = reg.predict(X)
print("The linear model is: Y = {:.5} + {:.5}X".format(reg.intercept_[0], reg.coef_[0][0]))
plt.figure(figsize=(16, 8))
plt.scatter(
    X,
    y,
    c='black'
)
plt.plot(
    X,
    predictions,
    c='blue',
    linewidth=2
)
plt.xlabel("reproduction_rate")
plt.ylabel("new_cases_smoothed")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-86-0c87988f85a8> in <module>
#       1 reg = LinearRegression()
# ----> 2 reg.fit(X, y)
#       3 predictions = reg.predict(X)
#       4 print("The linear model is: Y = {:.5} + {:.5}X".format(reg.intercept_[0], reg.coef_[0][0]))
#       5 plt.figure(figsize=(16, 8))
#
# ~\anaconda3\envs\MLEnv\lib\site-packages\sklearn\linear_model\_base.py in fit(self, X, y, sample_weight)
#     660         accept_sparse = False if self.positive else ["csr", "csc", "coo"]
#     661
# --> 662         X, y = self._validate_data(
#     663             X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     664         )
#
# ~\anaconda3\envs\MLEnv\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     579                 y = check_array(y, **check_y_params)
#     580             else:
# --> 581                 X, y = check_X_y(X, y, **check_params)
#     582             out = X, y
#     583
#
# ~\anaconda3\envs\MLEnv\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     979     y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric)
#     980
# --> 981     check_consistent_length(X, y)
#     982
#     983     return X, y
#
# ~\anaconda3\envs\MLEnv\lib\site-packages\sklearn\utils\validation.py in check_consistent_length(*arrays)
#     330     uniques = np.unique(lengths)
#     331     if len(uniques) > 1:
# --> 332         raise ValueError(
#     333             "Found input variables with inconsistent numbers of samples: %r"
#     334             % [int(l) for l in lengths]
#
# ValueError: Found input variables with inconsistent numbers of samples: [4907, 701]
